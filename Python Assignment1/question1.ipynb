# %% [markdown]
# # Question1
#
# -Under package Gutenberg, see what files are in it.
# Find out how many words and how many unique words in file 'austen-persuasion.txt'.
# -Calculate the frequency for each words and show the top 10 most frequent words and their frequency.
# Try NOT to use FreqDist module.

# %%
from nltk.corpus import gutenberg

len('austen-persuasion.txt')
words=gutenberg.words('austen-persuasion.txt')
print('words:',len(words))

print('unique words:',len(set(words)))
# Out:
# words: 98171
# unique words: 6132

# %%
import nltk
list1 = nltk.corpus.gutenberg.words('austen-persuasion.txt')

word_count = {}

for word in list1:
    if not word in word_count:
        word_count[word]=1
    else:
        word_count[word]=word_count[word]+1
                      

w=sorted(word_count.items(),key=lambda x:x[1],reverse=True)          
answer=w[:10]
print('Fre:',w)
# Out:
# Fre: [(',', 6750), ('the', 3120), ('to', 2775), ('.', 2741), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), (';', 1290), ('had', 1177), ('her', 1159), ('I', 1124), ('be', 949), ('not', 926), ('it', 857), ('that', 853), ('she', 819), ('"', 793), ('as', 787), ('he', 736), ('for', 695), ('with', 643), ('his', 625), ('have', 583), ('but', 553), ('you', 548), ("'", 525), ('at', 519), ('all', 517), ('Anne', 497), ('been', 496), ('s', 485), ('him', 467), ('could', 444), ('were', 426), ('very', 425), ('which', 415), ('by', 411), ('is', 393), ('on', 386), ('."', 369), ('would', 351), ('so', 338), ('She', 327), ('they', 323), ('no', 309), ('-', 308), ('Captain', 297), ('Mrs', 291), ('from', 290), ('Elliot', 288), ('or', 274), ('their', 273), ('them', 270), ('more', 269), ('Mr', 256), ('!', 253), ('than', 243), ('an', 238), ('must', 228), ('He', 225), ('one', 221), ('being', 220), ('Wentworth', 218), ('there', 216), ('only', 214), (',"', 213), ('The', 209), ('much', 205), ('this', 200), ('any', 198), ('such', 196), ('when', 196), ('my', 194), ('Lady', 191), ('do', 190), ('me', 188), ('who', 186), ('should', 185), ('It', 181), ('good', 181), ('little', 175), ('said', 173), ('what', 172), ('might', 166), ('Charles', 166), ('own', 163), ('if', 162), ('will', 162), ('herself', 158), ('did', 157), ('never', 153), ('time', 151), ('think', 149), ('Russell', 148), ('Sir', 144), ('now', 144), ('other', 142), ('Walter', 141), ('well', 141), ('are', 141), ('Mary', 138), ('am', 137), ('some', 135), ('man', 133), ('nothing', 131), ('again', 131), ('Musgrove', 130), ('too', 127), ('know', 127), (':', 124), ('Miss', 123), ('see', 123), ('most', 122), ('?', 122), ('soon', 121), ('father', 117), ('great', 116), ('before', 113), ('first', 112), ('two', 112), ('your', 112), ('But', 111), ('Louisa', 111), ('quite', 110), ('we', 110), ('They', 110), ('always', 109), ('though', 107), ('without', 106), ('--', 104), ('has', 100), ('can', 100), ('Bath', 99), ('into', 98), ('about', 96), ('made', 96), ('every', 96), ('out', 95), ('himself', 95), ('long', 95), ('say', 93), ('seemed', 93), ('up', 90), ('thought', 90), ('having', 90), ('Elizabeth', 89), ('last', 88), ('how', 88), ('?"', 88), ('make', 87), ('better', 87), ('go', 87), ('may', 87), ('over', 84), ('same', 84), ('friend', 83), ('home', 83), ('however', 83), ('young', 83), ('many', 83), ('found', 83), ('sister', 82), ('felt', 80), ('You', 80), ('like', 80), ('family', 79), ('house', 78), ('ever', 78), ('way', 78), ('away', 78), ('day', 77), ('give', 77), ('Uppercross', 77), ('after', 77), ('feelings', 75), ('room', 75), ('Harville', 75), ('Henrietta', 74), ('done', 74), ('sure', 73), ('Kellynch', 72), ('still', 72), ('come', 72), ('its', 72), ('those', 71), ('moment', 71), ('enough', 71), ('Benwick', 70), ('There', 70), ('(', 69), ('back', 69), ('off', 69), ('Smith', 68), ('woman', 67), ('Lyme', 67), ('came', 67), ('even', 67), ('Clay', 66), ('A', 66), ('just', 65), ('going', 65), ('present', 65), ('heard', 65), ('Admiral', 65), ('mind', 64), ('upon', 64), ('happy', 63), ('party', 62), ('And', 62), ('our', 62), ('another', 62), ('down', 61), ('!"', 61), ('acquaintance', 61), ('something', 61), ('knew', 61), ('few', 61), ('almost', 60), ('then', 60), ('rather', 60), ('morning', 58), ('Croft', 58), ('years', 58), ('half', 58), ('while', 58), ('seen', 58), ('wish', 58), ('yet', 55), ('shall', 55), ('evening', 55), ('others', 54), ('look', 54), ('together', 54), ('hope', 53), ('between', 53), ('Oh', 53), ('indeed', 52), ('ought', 52), ('once', 52), ('saw', 51), ('gone', 51), ('till', 50), ('perhaps', 50), ('take', 50), ('place', 50), ('This', 50), ('character', 49), ('life', 49), ('dear', 49), ('us', 48), ('left', 48), ('anything', 48), ('known', 48), ('poor', 48), ('short', 47), ('believe', 47), ('side', 47), ('here', 47), ('cried', 47), ('No', 47), ('where', 46), ('looking', 45), ('We', 45), ('possible', 45), ('near', 45), ('Her', 45), ('wife', 45), ('leave', 44), ('certainly', 44),  ...

# %%
print('Top10:')
print(answer)
# Out:
# Top10:
# [(',', 6750), ('the', 3120), ('to', 2775), ('.', 2741), ('and', 2739), ('of', 2564), ('a', 1529), ('in', 1346), ('was', 1330), (';', 1290)]
