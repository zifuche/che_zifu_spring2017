# %%
import requests
import json
import csv
import requests
import os
import datetime
import dateutil.rrule
from datetime import date, timedelta
import dateutil.relativedelta as relativedelta
import dateutil.rrule as rrule
import calendar
import glob
from nltk.probability import FreqDist
import pandas as pd

# %%
param={"client_id":"8_C4NSGbL05eUQksKleGYw",
      "client_secret":"Wfgy3xIJtzaEfSJfd4lGz5UwEZo9cT3PWoZ5h2q72zDNLxm0Tq35PT78v2Lu7fGJ",
      'grant_type': 'client_credentials'}
r=requests.post("https://api.yelp.com/oauth2/token",param)
r.json()
# Out:
# {'access_token': '5YSTNCxuTZHDmKDEJ15lI_ZQNNs0LJ--b6FHlIpm2cdiZbxijUbA1_4LYy6CTuYvT67SGrz0It76zXR75y0VdpaVwKmSlMTsD-KE2XK71LpIT8ZHKe4sh6hbiCnnWHYx',
#  'expires_in': 15487464,
#  'token_type': 'Bearer'}

# %%
access_token="5YSTNCxuTZHDmKDEJ15lI_ZQNNs0LJ--b6FHlIpm2cdiZbxijUbA1_4LYy6CTuYvT67SGrz0It76zXR75y0VdpaVwKmSlMTsD-KE2XK71LpIT8ZHKe4sh6hbiCnnWHYx"
url = 'https://api.yelp.com/v3/businesses/search'


headers={'Authorization': 'bearer %s' % access_token}

params = {'location': 'New York',
          'term':'Restaurant',
#            'pricing_filter': '1, 2',
#            'sort_by': 'rating',
          'offset':0,
          'limit':50
         }


r1=requests.get(url=url,params=params,headers=headers)
r1.json()
# Out:
# {'businesses': [{'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'coordinates': {'latitude': 40.7263139141197,
#     'longitude': -73.9864901976935},
#    'display_phone': '(917) 408-3395',
#    'distance': 2412.085390294,
#    'id': 'upstate-new-york-2',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/qJNkVkHcGWsprlouwX3siw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '95 1st Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['95 1st Ave', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Upstate',
#    'phone': '+19174083395',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 1338,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/upstate-new-york-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'tradamerican',
#      'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 40.7033988833427,
#     'longitude': -73.9906159043312},
#    'display_phone': '(718) 858-1095',
#    'distance': 373.04353140719996,
#    'id': 'atrium-dumbo-brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/BR-aI-c97_3kkNalDSoCFA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '15 Main St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['15 Main St', 'Brooklyn, NY 11201'],
#     'state': 'NY',
#     'zip_code': '11201'},
#    'name': 'Atrium Dumbo',
#    'phone': '+17188581095',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 383,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/atrium-dumbo-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'coordinates': {'latitude': 40.7327, 'longitude': -73.99766},
#    'display_phone': '(212) 533-2962',
#    'distance': 3035.998344844,
#    'id': 'amélie-new-york',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/cSDgVuPMnJgMLTrTNSEXug/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '22 W 8th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['22 W 8th St', 'New York, NY 10011'],
#     'state': 'NY',
#     'zip_code': '10011'},
#    'name': 'Amélie',
#    'phone': '+12125332962',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 1557,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/am%C3%A9lie-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 40.74016, 'longitude': -73.993372},
#    'display_phone': '(646) 833-7532',
#    'distance': 3861.19612028,
#    'id': 'burger-and-lobster-new-york',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MNX_b-3Mkt9C1rnP67c8IQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '39 W 19th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['39 W 19th St', 'New York, NY 10011'],
#     'state': 'NY',
#     'zip_code': '10011'},
#    'name': 'Burger & Lobster',
#    'phone': '+16468337532',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 3148,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/burger-and-lobster-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tapas', 'title': 'Tapas Bars'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'coordinates': {'latitude': 40.7459065, 'longitude': -73.915103},
#    'display_phone': '(347) 813-4159',
#    'distance': 8045.69013915,
#    'id': 'the-alcove-sunnyside',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gTEIryLzjD8ybcwwXYyFWw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '41-11 49th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Sunnyside',
#     'country': 'US',
#     'display_address': ['41-11 49th St', 'Sunnyside, NY 11104'],
#     'state': 'NY',
#     'zip_code': '11104'},
#    'name': 'The Alcove',
#    'phone': '+13478134159',
#    'price': '$$',
#    'rating': 5.0,
#    'review_count': 232,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-alcove-sunnyside?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 40.7608184814453,
#     'longitude': -73.9878463745117},
#    'display_phone': '(646) 918-6923',
#    'distance': 6180.808995108,
#    'id': 'dutch-freds-new-york-2',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/vijQyos6KXJ8t6V-Zhw7Bw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '307 W 47th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['307 W 47th St', 'New York, NY 10036'],
#     'state': 'NY',
#     'zip_code': '10036'},
#    'name': 'Dutch Freds',
#    'phone': '+16469186923',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 342,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/dutch-freds-new-york-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'coordinates': {'latitude': 40.7275047302246,
#     'longitude': -73.9838027954102},
#    'display_phone': '(646) 755-8088',
#    'distance': 2613.855588124,
#    'id': 'thursday-kitchen-new-york',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/k_KpsuXP4TKm6R7cJbJ85Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '424 E 9th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['424 E 9th St', 'New York, NY 10009'],
#     'state': 'NY',
#     'zip_code': '10009'},
#    'name': 'Thursday Kitchen',
#    'phone': '+16467558088',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 314,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/thursday-kitchen-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'thai', 'title': 'Thai'}],
#    'coordinates': {'latitude': 40.7390199, 'longitude': -73.99065},
#    'display_phone': '(212) 802-9999',
#    'distance': 3744.8381024019995,
#    'id': 'thai-villa-new-york-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/LWL2xzCuKZ0h0CBAAI-nig/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '5 E 19th St',
#     'address2': 'G Floor',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['5 E 19th St', 'G Floor', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Thai Villa',
#    'phone': '+12128029999',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 420,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/thai-villa-new-york-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.7025627046824,
#     'longitude': -73.9890079200268},
#    'display_phone': '(718) 855-5288',
#    'distance': 534.8106545384,
#    'id': 'almar-brooklyn-2',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/4HrrfAw2WL6oJ98Qu9ETXw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '111 Front St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['111 Front St', 'Brooklyn, NY 11201'],
#     'state': 'NY',
#     'zip_code': '11201'},
#    'name': 'AlMar',
#    'phone': '+17188555288',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 261,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/almar-brooklyn-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'modern_european', 'title': 'Modern European'}],
#    'coordinates': {'latitude': 40.727382, 'longitude': -74.000205},
#    'display_phone': '(212) 254-7000',
#    'distance': 2489.2627383999998,
#    'id': 'jane-new-york-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Uu0Wn-ACBmNGmDjbQu5w-A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '100 W Houston St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['100 W Houston St', 'New York, NY 10012'],
#     'state': 'NY',
#     'zip_code': '10012'},
#    'name': 'Jane',
#    'phone': '+12122547000',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 2577,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/jane-new-york-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'bars', 'title': 'Bars'}],
#    'coordinates': {'latitude': 40.732283, 'longitude': -73.999284},
#    'display_phone': '(212) 777-0303',
#    'distance': 3013.970825462,
#    'id': 'babbo-new-york',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/TBAbo22beco-TAV3hMGYKA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '110 Waverly Pl',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['110 Waverly Pl', 'New York, NY 10011'],
#     'state': 'NY',
#     'zip_code': '10011'},
#    'name': 'Babbo',
#    'phone': '+12127770303',
#    'price': '$$$$',
#    'rating': 4.0,
#    'review_count': 2038,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/babbo-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'desserts', 'title': 'Desserts'}],
#    'coordinates': {'latitude': 40.679115, 'longitude': -74.010459},
#    'display_phone': '(718) 909-2881',
#    'distance': 3229.3917670399996,
#    'id': 'grindhaus-new-york-2',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_ju4M5RwOyOOUK9j8BdSxQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '275 Van Brunt St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['275 Van Brunt St', 'New York, NY 11231'],
#     'state': 'NY',
#     'zip_code': '11231'},
#    'name': 'Grindhaus',
#    'phone': '+17189092881',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 59,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/grindhaus-new-york-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'coordinates': {'latitude': 40.76428, 'longitude': -73.98172},
#    'display_phone': '(646) 590-2034',
#    'distance': 6634.17584464,
#    'id': 'tanner-smiths-new-york-2',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/_Essm9xziNyC_7VByXTpjA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '204 W 55th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['204 W 55th St', 'New York, NY 10019'],
#     'state': 'NY',
#     'zip_code': '10019'},
#    'name': 'Tanner Smiths',
#    'phone': '+16465902034',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 578,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/tanner-smiths-new-york-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 40.748821, 'longitude': -73.940719},
#    'display_phone': '(718) 482-7507',
#    'distance': 6606.178156659999,
#    'id': 'the-beast-next-door-long-island-city',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/m1F7u7Lim5P31LwJOYgdYA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '42-51 27th St',
#     'address2': '',
#     'address3': '',
#     'city': 'Long Island City',
#     'country': 'US',
#     'display_address': ['42-51 27th St', 'Long Island City, NY 11101'],
#     'state': 'NY',
#     'zip_code': '11101'},
#    'name': 'The Beast Next Door',
#    'phone': '+17184827507',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 102,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-beast-next-door-long-island-city?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'salad', 'title': 'Salad'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#     {'alias': 'sandwiches', 'title': 'Sandwiches'}],
#    'coordinates': {'latitude': 40.73287, 'longitude': -73.95448},
#    'display_phone': '(718) 383-5615',
#    'distance': 4520.19027282,
#    'id': 'the-habitat-brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/YZzZ7MXpMG3wpgXb73VTeA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '988 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['988 Manhattan Ave', 'Brooklyn, NY 11222'],
#     'state': 'NY',
#     'zip_code': '11222'},
#    'name': 'The Habitat',
#    'phone': '+17183835615',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 218,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-habitat-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'seafood', 'title': 'Seafood'}],
#    'coordinates': {'latitude': 40.7046213003984,
#     'longitude': -74.0107793876969},
#    'display_phone': '(212) 747-1700',
#    'distance': 1392.786083062,
#    'id': 'lukes-lobster-fidi-new-york',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/95avsfywd4zW4MjtyiIo9A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '26 S William St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['26 S William St', 'New York, NY 10004'],
#     'state': 'NY',
#     'zip_code': '10004'},
#    'name': "Luke's Lobster FiDi",
#    'phone': '+12127471700',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 766,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/lukes-lobster-fidi-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'coordinates': {'latitude': 40.7591968, 'longitude': -73.9923361},
#    'display_phone': '(212) 602-1910',
#    'distance': 5979.3260644679995,
#    'id': 'bea-new-york',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/hFAPke48g0zVB7oBUWA6JA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '403 W 43rd St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['403 W 43rd St', 'New York, NY 10036'],
#     'state': 'NY',
#     'zip_code': '10036'},
#    'name': 'Bea',
#    'phone': '+12126021910',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1211,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/bea-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'coordinates': {'latitude': 40.6918206366101,
#     'longitude': -73.9863992364001},
#    'display_phone': '(929) 337-7599',
#    'distance': 1654.5505448839997,
#    'id': 'yaso-tangbao-brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/n8qkl-utd4uCMlOy46G05g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '148 Lawrence St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['148 Lawrence St', 'Brooklyn, NY 11201'],
#     'state': 'NY',
#     'zip_code': '11201'},
#    'name': 'Yaso Tangbao',
#    'phone': '+19293377599',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 366,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/yaso-tangbao-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'moroccan', 'title': 'Moroccan'},
#     {'alias': 'mideastern', 'title': 'Middle Eastern'}],
#    'coordinates': {'latitude': 40.719747, 'longitude': -73.959993},
#    'display_phone': '(718) 486-9222',
#    'distance': 3299.60002921,
#    'id': 'cafe-mogador-brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/vKOnSpZPeLG2Nk7URi1CAw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '133 Wythe Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['133 Wythe Ave', 'Brooklyn, NY 11211'],
#     'state': 'NY',
#     'zip_code': '11211'},
#    'name': 'Cafe Mogador',
#    'phone': '+17184869222',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 763,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/cafe-mogador-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'ramen', 'title': 'Ramen'},
#     {'alias': 'burgers', 'title': 'Burgers'}],
#    'coordinates': {'latitude': 40.7554119, 'longitude': -73.9414266},
#    'display_phone': '(929) 522-0285',
#    'distance': 7121.3793895399995,
#    'id': 'ramen-shack-long-island-city-3',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/WIUC_gTgzfuCgD0k5w8ypg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '13-13 40th Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'Long Island City',
#     'country': 'US',
#     'display_address': ['13-13 40th Ave', 'Long Island City, NY 11101'],
#     'state': 'NY',
#     'zip_code': '11101'},
#    'name': 'Ramen Shack',
#    'phone': '+19295220285',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 48,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/ramen-shack-long-island-city-3?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'mediterranean', 'title': 'Mediterranean'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 40.72213, 'longitude': -73.99756},
#    'display_phone': '(212) 510-8550',
#    'distance': 1875.9661170279999,
#    'id': 'jacks-wife-freda-new-york',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/WdTzlh8NNKLgmxlkHlrGLw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '224 Lafayette St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['224 Lafayette St', 'New York, NY 10012'],
#     'state': 'NY',
#     'zip_code': '10012'},
#    'name': "Jack's Wife Freda",
#    'phone': '+12125108550',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1137,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/jacks-wife-freda-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'asianfusion', 'title': 'Asian Fusion'}],
#    'coordinates': {'latitude': 40.70717, 'longitude': -74.00192},
#    'display_phone': '(917) 363-8101',
#    'distance': 664.9587528216,
#    'id': 'fishmarket-restaurant-new-york',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/BxY50B6ntFYQa8COuI1Fog/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '111 South St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['111 South St', 'New York, NY 10038'],
#     'state': 'NY',
#     'zip_code': '10038'},
#    'name': 'Fishmarket Restaurant',
#    'phone': '+19173638101',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 318,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/fishmarket-restaurant-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'french', 'title': 'French'},
#     {'alias': 'korean', 'title': 'Korean'}],
#    'coordinates': {'latitude': 40.68742, 'longitude': -73.98258},
#    'display_phone': '(917) 909-0970',
#    'distance': 2239.90998946,
#    'id': 'brasserie-séoul-brooklyn-2',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/A9yvd4Ti-eAdxXBgajdF0w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '300 Schermerhorn St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['300 Schermerhorn St', 'Brooklyn, NY 11217'],
#     'state': 'NY',
#     'zip_code': '11217'},
#    'name': 'Brasserie Séoul',
#    'phone': '+19179090970',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 129,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/brasserie-s%C3%A9oul-brooklyn-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'shanghainese', 'title': 'Shanghainese'}],
#    'coordinates': {'latitude': 40.7146691442891,
#     'longitude': -73.9977602206654},
#    'display_phone': '(212) 233-8888',
#    'distance': 1066.3967067056,
#    'id': 'joes-shanghai-new-york-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/ekUo5egd4dlE7zJyb4-Leg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '9 Pell St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['9 Pell St', 'New York, NY 10013'],
#     'state': 'NY',
#     'zip_code': '10013'},
#    'name': "Joe's Shanghai",
#    'phone': '+12122338888',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 4293,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/joes-shanghai-new-york-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'tradamerican', 'title': 'American (Traditional)'}],
#    'coordinates': {'latitude': 40.7866504411994,
#     'longitude': -73.9755284786224},
#    'display_phone': '(212) 470-5566',
#    'distance': 9167.202975,
#    'id': 'jacobs-pickles-new-york',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/gAPSgXM0l_YTh3nrCi_-fg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '509 Amsterdam Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['509 Amsterdam Ave', 'New York, NY 10024'],
#     'state': 'NY',
#     'zip_code': '10024'},
#    'name': "Jacob's Pickles",
#    'phone': '+12124705566',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 2449,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/jacobs-pickles-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 40.747934281826,
#     'longitude': -74.0025658160448},
#    'display_phone': '(212) 645-5660',
#    'distance': 4832.788957221999,
#    'id': 'rocket-pig-new-york',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5HHcM-oqvenpKyK4WURoYw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '463 W 24th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['463 W 24th St', 'New York, NY 10001'],
#     'state': 'NY',
#     'zip_code': '10001'},
#    'name': 'Rocket Pig',
#    'phone': '+12126455660',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 147,
#    'transactions': ['delivery'],
#    'url': 'https://www.yelp.com/biz/rocket-pig-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'burgers', 'title': 'Burgers'},
#     {'alias': 'mexican', 'title': 'Mexican'}],
#    'coordinates': {'latitude': 40.7166907225542,
#     'longitude': -73.9999440120647},
#    'display_phone': '(212) 227-2802',
#    'distance': 1338.1788594124,
#    'id': 'breakroom-new-york',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/erA6rW1fUVn3VTTXo7PJRA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '83 Baxter St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['83 Baxter St', 'New York, NY 10013'],
#     'state': 'NY',
#     'zip_code': '10013'},
#    'name': 'Breakroom',
#    'phone': '+12122272802',
#    'price': '$',
#    'rating': 4.5,
#    'review_count': 1132,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/breakroom-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'}],
#    'coordinates': {'latitude': 40.70861, 'longitude': -74.01362},
#    'display_phone': '(212) 732-5005',
#    'distance': 1664.5054393219998,
#    'id': 'suspenders-new-york',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/_i2U8uRVvBN8D4U8_1gvcg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '108 Greenwich St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['108 Greenwich St', 'New York, NY 10006'],
#     'state': 'NY',
#     'zip_code': '10006'},
#    'name': 'Suspenders',
#    'phone': '+12127325005',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 58,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/suspenders-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 40.67713, 'longitude': -73.96869},
#    'display_phone': '(718) 552-2610',
#    'distance': 3824.6201672979996,
#    'id': 'olmsted-brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DJ8uGKbWSF1Crper_87XWg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '659 Vanderbilt Ave',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['659 Vanderbilt Ave', 'Brooklyn, NY 11238'],
#     'state': 'NY',
#     'zip_code': '11238'},
#    'name': 'Olmsted',
#    'phone': '+17185522610',
#    'price': '$$$',
#    'rating': 4.0,
#    'review_count': 103,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/olmsted-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'hawaiian', 'title': 'Hawaiian'},
#     {'alias': 'poke', 'title': 'Poke'}],
#    'coordinates': {'latitude': 40.71787, 'longitude': -73.99948},
#    'display_phone': '(646) 649-5965',
#    'distance': 1456.215000482,
#    'id': 'chikarashi-new-york',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/wCaNTJZPFYMBrsgnTwkRLw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '227 Canal St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['227 Canal St', 'New York, NY 10013'],
#     'state': 'NY',
#     'zip_code': '10013'},
#    'name': 'Chikarashi',
#    'phone': '+16466495965',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 312,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/chikarashi-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'korean', 'title': 'Korean'},
#     {'alias': 'gastropubs', 'title': 'Gastropubs'},
#     {'alias': 'tapasmallplates', 'title': 'Tapas/Small Plates'}],
#    'coordinates': {'latitude': 40.749641418457,
#     'longitude': -73.9858245849609},
#    'display_phone': '(212) 564-4430',
#    'distance': 4967.470598472,
#    'id': 'barn-joo-35-new-york',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/5uqtr9nMVvCaIqbdr7sxpw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '34 W 35th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['34 W 35th St', 'New York, NY 10001'],
#     'state': 'NY',
#     'zip_code': '10001'},
#    'name': 'Barn Joo 35',
#    'phone': '+12125644430',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 405,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/barn-joo-35-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'mexican', 'title': 'Mexican'}],
#    'coordinates': {'latitude': 40.7034683227539,
#     'longitude': -73.9121246337891},
#    'display_phone': '(718) 552-2811',
#    'distance': 6931.919838039999,
#    'id': 'palomas-brooklyn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/BUGMkK4DUbpNp9MOKrx02A/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '435 Menahan St',
#     'address2': None,
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['435 Menahan St', 'Brooklyn, NY 11237'],
#     'state': 'NY',
#     'zip_code': '11237'},
#    'name': 'Palomas',
#    'phone': '+17185522811',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 31,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/palomas-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 40.7535743713379,
#     'longitude': -73.9914321899414},
#    'display_phone': '(212) 994-9599',
#    'distance': 5364.635754655999,
#    'id': 'district-social-new-york',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/prQBUjUQR5iOSmIeVsACUQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '252 W 37th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['252 W 37th St', 'New York, NY 10018'],
#     'state': 'NY',
#     'zip_code': '10018'},
#    'name': 'District Social',
#    'phone': '+12129949599',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 187,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/district-social-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'southern', 'title': 'Southern'},
#     {'alias': 'whiskeybars', 'title': 'Whiskey Bars'}],
#    'coordinates': {'latitude': 40.6789820209096,
#     'longitude': -73.9680890366435},
#    'display_phone': '(718) 975-7555',
#    'distance': 3679.7124578199996,
#    'id': 'tin-kettle-brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/HGvygv4-fdcM-WapKXJSbw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '611 Vanderbilt Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['611 Vanderbilt Ave', 'Brooklyn, NY 11238'],
#     'state': 'NY',
#     'zip_code': '11238'},
#    'name': 'Tin Kettle',
#    'phone': '+17189757555',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 44,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/tin-kettle-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'tradamerican', 'title': 'American (Traditional)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'brasseries', 'title': 'Brasseries'}],
#    'coordinates': {'latitude': 40.755165, 'longitude': -73.967868},
#    'display_phone': '(212) 644-2700',
#    'distance': 5960.327644834,
#    'id': 'the-smith-new-york-2',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/f9QUNmbKB8X2ldrGRDerBg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '956 2nd Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['956 2nd Ave', 'New York, NY 10022'],
#     'state': 'NY',
#     'zip_code': '10022'},
#    'name': 'The Smith',
#    'phone': '+12126442700',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1469,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-smith-new-york-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'cafes', 'title': 'Cafes'}],
#    'coordinates': {'latitude': 40.6901735, 'longitude': -73.9069755},
#    'display_phone': '(718) 975-6840',
#    'distance': 7554.5293881239995,
#    'id': 'father-knows-best-brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MHn1tidAa4Xm0I4dvzoL_Q/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '611A Wilson Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['611A Wilson Ave', 'Brooklyn, NY 11207'],
#     'state': 'NY',
#     'zip_code': '11207'},
#    'name': 'Father Knows Best',
#    'phone': '+17189756840',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 64,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/father-knows-best-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 40.738527, 'longitude': -73.988417},
#    'display_phone': '(212) 477-0777',
#    'distance': 3711.6068407419993,
#    'id': 'gramercy-tavern-new-york',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/yr_BNXJ57Q66IgSppMy1Qw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '42 E 20th St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['42 E 20th St', 'New York, NY 10003'],
#     'state': 'NY',
#     'zip_code': '10003'},
#    'name': 'Gramercy Tavern',
#    'phone': '+12124770777',
#    'price': '$$$$',
#    'rating': 4.5,
#    'review_count': 2194,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/gramercy-tavern-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'soulfood', 'title': 'Soul Food'}],
#    'coordinates': {'latitude': 40.693866, 'longitude': -73.964535},
#    'display_phone': '(718) 783-1936',
#    'distance': 2819.4191612679997,
#    'id': 'soco-brooklyn',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/p-ZscwZQaZsG0KenHEaLZg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '509 Myrtle Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['509 Myrtle Ave', 'Brooklyn, NY 11205'],
#     'state': 'NY',
#     'zip_code': '11205'},
#    'name': 'Soco',
#    'phone': '+17187831936',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1448,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/soco-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'}],
#    'coordinates': {'latitude': 40.69979, 'longitude': -73.99203},
#    'display_phone': '(718) 625-3737',
#    'distance': 655.4880122292,
#    'id': 'noodle-pudding-brooklyn',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/a9hX2-KJ1-hhe5-VRpTbpA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '38 Henry St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['38 Henry St', 'Brooklyn, NY 11201'],
#     'state': 'NY',
#     'zip_code': '11201'},
#    'name': 'Noodle Pudding',
#    'phone': '+17186253737',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 440,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/noodle-pudding-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'wine_bars', 'title': 'Wine Bars'},
#     {'alias': 'comfortfood', 'title': 'Comfort Food'},
#     {'alias': 'gluten_free', 'title': 'Gluten-Free'}],
#    'coordinates': {'latitude': 40.772189, 'longitude': -73.955029},
#    'display_phone': '(212) 249-0069',
#    'distance': 8125.532715230001,
#    'id': 'heidis-house-by-the-side-of-the-road-new-york-2',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/X3Yt1SKN2mUO09c-zBrcAA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '308 E 78th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['308 E 78th St', 'New York, NY 10075'],
#     'state': 'NY',
#     'zip_code': '10075'},
#    'name': "Heidi's House By The Side Of The Road",
#    'phone': '+12122490069',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 467,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/heidis-house-by-the-side-of-the-road-new-york-2?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'bars', 'title': 'Bars'},
#     {'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'venues', 'title': 'Venues & Event Spaces'}],
#    'coordinates': {'latitude': 40.7502555847168,
#     'longitude': -73.9854583740234},
#    'display_phone': '(646) 858-2320',
#    'distance': 5039.060318098,
#    'id': 'trademark-taste-and-grind-new-york',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/qG7m1tWaPYv7ALUqtZuA0g/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '38 W 36th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['38 W 36th St', 'New York, NY 10018'],
#     'state': 'NY',
#     'zip_code': '10018'},
#    'name': 'Trademark Taste & Grind',
#    'phone': '+16468582320',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 173,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/trademark-taste-and-grind-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#    'coordinates': {'latitude': 40.675919, 'longitude': -73.999059},
#    'display_phone': '(718) 852-8490',
#    'distance': 3307.6346591599995,
#    'id': 'buttermilk-channel-brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/61-SlAWvGO4U8W6KZaCjSw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '524 Court St',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['524 Court St', 'Brooklyn, NY 11231'],
#     'state': 'NY',
#     'zip_code': '11231'},
#    'name': 'Buttermilk Channel',
#    'phone': '+17188528490',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1506,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/buttermilk-channel-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 40.68146, 'longitude': -73.95589},
#    'display_phone': '(718) 636-6228',
#    'distance': 4198.1380033899995,
#    'id': 'harts-restaurant-new-york',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/6d-N-9j0t6BeHvBwEmp8XA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '506 Franklin Ave',
#     'address2': '',
#     'address3': None,
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['506 Franklin Ave', 'New York, NY 11238'],
#     'state': 'NY',
#     'zip_code': '11238'},
#    'name': "Hart's Restaurant",
#    'phone': '+17186366228',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 15,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/harts-restaurant-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'coordinates': {'latitude': 40.7454251, 'longitude': -74.0056084},
#    'display_phone': '(212) 924-4440',
#    'distance': 4554.6752103399995,
#    'id': 'cookshop-new-york',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XBmHegqbtMc7KBBiAl6YpA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '156 10th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['156 10th Ave', 'New York, NY 10011'],
#     'state': 'NY',
#     'zip_code': '10011'},
#    'name': 'Cookshop',
#    'phone': '+12129244440',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 1555,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/cookshop-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'}],
#    'coordinates': {'latitude': 40.739131, 'longitude': -74.003631},
#    'display_phone': '(646) 896-1404',
#    'distance': 3829.60236207,
#    'id': 'coarse-nyc-new-york',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/JC5xkyMnrBFDJ0Q9_tvYJg/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '306 W 13th St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['306 W 13th St', 'New York, NY 10014'],
#     'state': 'NY',
#     'zip_code': '10014'},
#    'name': 'Coarse NYC',
#    'phone': '+16468961404',
#    'price': '$$$',
#    'rating': 4.5,
#    'review_count': 43,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/coarse-nyc-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'newamerican', 'title': 'American (New)'},
#     {'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'coordinates': {'latitude': 40.6797733227923,
#     'longitude': -73.9752304111946},
#    'display_phone': '(718) 857-2473',
#    'distance': 3276.1485657959997,
#    'id': 'purbird-brooklyn',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/woDMEFfHX0Ty20layZ0uDQ/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '82 Sixth Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['82 Sixth Ave', 'Brooklyn, NY 11217'],
#     'state': 'NY',
#     'zip_code': '11217'},
#    'name': 'Purbird',
#    'phone': '+17188572473',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 359,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/purbird-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'coordinates': {'latitude': 40.7364097, 'longitude': -73.9550825},
#    'display_phone': '(718) 389-0160',
#    'distance': 4771.999518336,
#    'id': 'milk-and-roses-brooklyn',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/KSUwldaoTnz02gpdT_2kRw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '1110 Manhattan Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['1110 Manhattan Ave', 'Brooklyn, NY 11222'],
#     'state': 'NY',
#     'zip_code': '11222'},
#    'name': 'Milk And Roses',
#    'phone': '+17183890160',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 254,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/milk-and-roses-brooklyn?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'cajun', 'title': 'Cajun/Creole'},
#     {'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'wine_bars', 'title': 'Wine Bars'}],
#    'coordinates': {'latitude': 40.719683, 'longitude': -73.993304},
#    'display_phone': '(212) 925-8815',
#    'distance': 1585.6485839919999,
#    'id': 'the-boil-new-york-3',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/DB3GaP5qWE-3VTXu44JQ_w/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '139 Chrystie St',
#     'address2': None,
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['139 Chrystie St', 'New York, NY 10002'],
#     'state': 'NY',
#     'zip_code': '10002'},
#    'name': 'The Boil',
#    'phone': '+12129258815',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 1359,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/the-boil-new-york-3?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'italian', 'title': 'Italian'},
#     {'alias': 'cocktailbars', 'title': 'Cocktail Bars'}],
#    'coordinates': {'latitude': 40.71087, 'longitude': -74.00753},
#    'display_phone': '(212) 285-2668',
#    'distance': 1262.21421337,
#    'id': 'da-claudio-new-york',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/XLxqA77QYDZwKS_h6tGdWw/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '21 Ann St',
#     'address2': '',
#     'address3': '',
#     'city': 'New York',
#     'country': 'US',
#     'display_address': ['21 Ann St', 'New York, NY 10038'],
#     'state': 'NY',
#     'zip_code': '10038'},
#    'name': 'Da Claudio',
#    'phone': '+12122852668',
#    'price': '$$',
#    'rating': 4.5,
#    'review_count': 224,
#    'transactions': ['delivery', 'pickup'],
#    'url': 'https://www.yelp.com/biz/da-claudio-new-york?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'},
#   {'categories': [{'alias': 'vietnamese', 'title': 'Vietnamese'},
#     {'alias': 'coffee', 'title': 'Coffee & Tea'},
#     {'alias': 'salad', 'title': 'Salad'}],
#    'coordinates': {'latitude': 40.6814048, 'longitude': -73.9771062},
#    'display_phone': '(718) 857-3483',
#    'distance': 3040.7014800599995,
#    'id': '5ive-spice-brooklyn-3',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/-1hep-WamKvcCf66pWynhA/o.jpg',
#    'is_closed': False,
#    'location': {'address1': '52 5th Ave',
#     'address2': '',
#     'address3': '',
#     'city': 'Brooklyn',
#     'country': 'US',
#     'display_address': ['52 5th Ave', 'Brooklyn, NY 11217'],
#     'state': 'NY',
#     'zip_code': '11217'},
#    'name': '5ive Spice',
#    'phone': '+17188573483',
#    'price': '$$',
#    'rating': 4.0,
#    'review_count': 290,
#    'transactions': [],
#    'url': 'https://www.yelp.com/biz/5ive-spice-brooklyn-3?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'}],
#  'region': {'center': {'latitude': 40.70544486444615,
#    'longitude': -73.99429321289062}},
#  'total': 39340}

# %%
offestlist=list(range(780))

# %%
def writejson(offset,r):    
    with open(os.getcwd()+"/raw data/NY-Restaurant/"+str(offset)+'.json', 'w',encoding='utf-8',errors='ignore') as outfile:
        json.dump(r, outfile)

# %%
def collectdata():
    for num in offestlist:      
        params = {'location': 'New York',
                  'term':'Restaurant',
#            'pricing_filter': '1, 2',
#            'sort_by': 'rating',
          'offset':num,
          'limit':50 }
        r=requests.get(url=url,params=params,headers=headers)
        writejson(num,r.json())

# %%
collectdata()

# %%
# url ='https://api.yelp.com/v3/businesses/delice-and-sarrasin-new-york/reviews'
# r1=requests.get(url=url,headers=headers)
# r1.json()

# %%
def readjson(path):                                               #read json
    with open(path,'r',encoding='utf-8',errors='ignore') as df:
        data=json.load(df)
        return data

# %%
def writecsv(x):
    with open(os.getcwd()+"/NY-restaurant.csv", 'a') as outcsv:      
        writer=csv.writer(outcsv,delimiter=',', quotechar='|',quoting=csv.QUOTE_MINIMAL, lineterminator='\n')   
        ree=x["businesses"]
        for item in ree:
            c1=item["id"].replace(","," ")
            c2=item["name"].replace(","," ")
            c3=item["display_phone"]
            c4=item["rating"]
            c5=item["review_count"]
            if len(item["transactions"])==0:
                c6=None
            else:            
                c6=item["transactions"][0]
            c7=item["coordinates"]["latitude"]
            c8=item["coordinates"]["longitude"]
            c9=item["location"]["city"].replace(","," ")
            if item["location"]["address1"]==None:
                c10=None
            else:
                c10=item["location"]["address1"].replace(","," ")
            if item["location"]["address2"]==None:
                c11=None
            else:
                c11=item["location"]["address2"].replace(","," ")
            if item["location"]["address3"]==None:
                c12=None
            else:
                c12=item["location"]["address3"].replace(","," ")    
            c13=item["location"]["zip_code"].replace(","," ")
            c14=item["distance"]
            if len(item["categories"])>2:
                c15=item["categories"][0]["title"].replace(","," ")
                c16=item["categories"][1]["title"].replace(","," ")
                c17=item["categories"][2]["title"].replace(","," ")
            if len(item["categories"])==2:
                c15=item["categories"][0]["title"].replace(","," ")
                c16=item["categories"][1]["title"].replace(","," ")
                c17=None
            if len(item["categories"])==1:
                c15=item["categories"][0]["title"].replace(","," ")
                c16=None
                c17=None  
            if len(item["categories"])==0:
                c15=None
                c16=None
                c17=None 
            if 'price' not in item:
                c18=None
            else:
                c18=item['price']
            writer.writerow([c1,c2,c3,c4,c5,c6,c7,c8,c9,c10,c11,c12,c13,c14,c15,c16,c17,c18])

# %%
def writehead():
    with open(os.getcwd()+"/NY-restaurant.csv", 'a') as outcsv:      
        writer=csv.writer(outcsv,delimiter=',', quotechar='|',quoting=csv.QUOTE_MINIMAL, lineterminator='\n')   
        writer.writerow(["id","name","phone","rating","reviewcount","transactions","latitude","longitude","city","address1","address2","address3","zip_code","distance","categories1","categories2","categories3","price"])

# %%
cc["businesses"][2]
# Out:
# {'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'},
#   {'alias': 'tapas', 'title': 'Tapas Bars'},
#   {'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'}],
#  'coordinates': {'latitude': 40.7459065, 'longitude': -73.915103},
#  'display_phone': '(347) 813-4159',
#  'distance': 8045.69013915,
#  'id': 'the-alcove-sunnyside',
#  'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/gTEIryLzjD8ybcwwXYyFWw/o.jpg',
#  'is_closed': False,
#  'location': {'address1': '41-11 49th St',
#   'address2': '',
#   'address3': '',
#   'city': 'Sunnyside',
#   'country': 'US',
#   'display_address': ['41-11 49th St', 'Sunnyside, NY 11104'],
#   'state': 'NY',
#   'zip_code': '11104'},
#  'name': 'The Alcove',
#  'phone': '+13478134159',
#  'price': '$$',
#  'rating': 5.0,
#  'review_count': 232,
#  'transactions': [],
#  'url': 'https://www.yelp.com/biz/the-alcove-sunnyside?adjust_creative=8_C4NSGbL05eUQksKleGYw&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=8_C4NSGbL05eUQksKleGYw'}

# %%
cc=readjson(os.getcwd()+"/raw data/NY-Restaurant/2.json")

# %%
pathlist=glob.glob(os.getcwd()+"/raw data/NY-Restaurant/*.json")

# %%
def outputcsv(pathlist):
    for path in pathlist:
        r=readjson(path)
        writecsv(r)

# %%
if os.path.exists(os.getcwd()+"/NY-restaurant.csv"):
    os.remove(os.getcwd()+"/NY-restaurant.csv") 
writehead()    
outputcsv(pathlist)
