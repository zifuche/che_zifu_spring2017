# %%
import requests
import os
import json
import datetime
import dateutil.rrule
import glob
from nltk.probability import FreqDist

# %%
from datetime import timedelta, date

from dateutil.rrule import rrule, MONTHLY

# %%
import calendar
import datetime

def months_iter(start_month, start_year, end_month, end_year):
    start_date = datetime.date(start_year, start_month, 1)
    end_date = datetime.date(end_year, end_month, 1)
    date = start_date
    while date <= end_date:
        yield (date.month, date.year)
        days_in_month = calendar.monthrange(date.year, date.month)[1]
        date += datetime.timedelta(days_in_month)

def months(start_month, start_year, end_month, end_year):
    return tuple(d for d in months_iter(start_month, start_year, end_month, end_year))

# %%
def ensure_dir(path):                                   # create folder if not exist
    directory = os.path.dirname(path)
    if not os.path.exists(directory):
        os.makedirs(directory)

# %%
print (months(8, 2010, 3, 2011))
l=months(8, 2010, 3, 2011)
print(l[1][1])
# Out:
# ((8, 2010), (9, 2010), (10, 2010), (11, 2010), (12, 2010), (1, 2011), (2, 2011), (3, 2011))
# 2010

# %%
def writejson(year,month,r):    
    with open(os.path.dirname(os.getcwd())+"/raw data/archive/"+str(year)+'-'+str(month)+'.json', 'w',encoding='utf-8',errors='ignore') as outfile:
        json.dump(r, outfile)

# %%
# print(len(data['response']['docs']))

# %%
def getjson(startmonth,startyear,endmonth,endyear):
    for date in months(startmonth,startyear,endmonth,endyear):
        r = requests.get("https://api.nytimes.com/svc/archive/v1/"+str(date[1])+"/"+str(date[0])+".json?&api-key="+os.getenv('auth_key'))
        writejson(date[1],date[0],r.json())

# %%
print(os.getenv('auth_key')) #export auth_key=8220f32e060a428bb41d0f881f18dc39
# Out:
# 8220f32e060a428bb41d0f881f18dc39

# %%
getjson(12,2007,1,2017)

# %%
def readjson(path):                                               #read json
    with open(path,'r',encoding='utf-8',errors='ignore') as df:
        data=json.load(df)
        return data

# %%
s=readjson(os.path.dirname(os.getcwd())+"/raw data/archive/2014-1.json")
s
# Out:
# {'copyright': 'Copyright (c) 2013 The New York Times Company.  All Rights Reserved.',
#  'response': {'docs': [{'_id': '52bca6f538f0d8377a7ad5cc',
#     'abstract': None,
#     'blog': [],
#     'byline': [],
#     'document_type': 'multimedia',
#     'headline': {'main': 'Pageant of a Bucolic Ukraine'},
#     'keywords': [{'is_major': 'N',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Restaurants'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '2',
#       'value': 'SoHo (Manhattan, NY)'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '3',
#       'value': 'Korchma Taras Bulba (Manhattan, NY, Restaurant)'}],
#     'lead_paragraph': 'Korchma Taras Bulba opened its first New York restaurant in SoHo, featuring Ukrainian food and servers in traditional dress.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/dining/20140101-HUNGRY-slide-N5S0/20140101-HUNGRY-slide-N5S0-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/20140101-HUNGRY-slide-N5S0/20140101-HUNGRY-slide-N5S0-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2014/01/01/dining/20140101-HUNGRY-slide-N5S0/20140101-HUNGRY-slide-N5S0-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/20140101-HUNGRY-slide-N5S0/20140101-HUNGRY-slide-N5S0-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/dining/20140101-HUNGRY-slide-N5S0/20140101-HUNGRY-slide-N5S0-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/20140101-HUNGRY-slide-N5S0/20140101-HUNGRY-slide-N5S0-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Food',
#     'print_page': None,
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Food',
#     'slideshow_credits': None,
#     'snippet': 'Korchma Taras Bulba opened its first New York restaurant in SoHo, featuring Ukrainian food and servers in traditional dress.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'Slideshow',
#     'web_url': 'http://www.nytimes.com/slideshow/2014/01/01/dining/20140101-HUNGRY.html',
#     'word_count': '19'},
#    {'_id': '52bca70038f0d8377a7ad5cd',
#     'abstract': 'Julia Moskin Hungry City column reviews Korchma Taras Bulba restaurant in SoHo.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By JULIA MOSKIN',
#      'person': [{'firstname': 'Julia',
#        'lastname': 'MOSKIN',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Hungry City',
#      'kicker': 'Hungry City | Korchma Taras Bulba',
#      'main': 'A Day in SoHo, a Night in Ukraine',
#      'print_headline': 'A Day in SoHo, a Night in Ukraine',
#      'seo': 'Hungry City: Korchma Taras Bulba in SoHo'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Restaurants'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '2',
#       'value': 'SoHo (Manhattan, NY)'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '3',
#       'value': 'Korchma Taras Bulba (Manhattan, NY, Restaurant)'}],
#     'lead_paragraph': 'Part restaurant, part folk performance, Korchma Taras Bulba keeps the dumplings and vodka shots coming.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/dining/20140101-HUNGRY-slide-IFNX/20140101-HUNGRY-slide-IFNX-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/20140101-HUNGRY-slide-IFNX/20140101-HUNGRY-slide-IFNX-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2014/01/01/dining/20140101-HUNGRY-slide-IFNX/20140101-HUNGRY-slide-IFNX-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/20140101-HUNGRY-slide-IFNX/20140101-HUNGRY-slide-IFNX-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/dining/20140101-HUNGRY-slide-IFNX/20140101-HUNGRY-slide-IFNX-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/20140101-HUNGRY-slide-IFNX/20140101-HUNGRY-slide-IFNX-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Dining',
#     'print_page': '6',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Food',
#     'slideshow_credits': None,
#     'snippet': 'Part restaurant, part folk performance, Korchma Taras Bulba keeps the dumplings and vodka shots coming.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'Review',
#     'web_url': 'http://www.nytimes.com/2014/01/01/dining/a-day-in-soho-a-night-in-ukraine.html',
#     'word_count': '763'},
#    {'_id': '52bda55e38f0d8377a7ad8a7',
#     'abstract': 'Argentinian winemakers are putting an intriguing spin on what is usually known as a Bordeaux blend, relying primarily on mix of cabernet sauvignon and malbec.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By FLORENCE FABRICANT',
#      'person': [{'firstname': 'Florence',
#        'lastname': 'FABRICANT',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Argentina Tries to Give Malbec More Status',
#      'print_headline': 'Argentina Tries to Give Malbec More Status'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Wines'},
#      {'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '3',
#       'value': 'Argentina'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '2',
#       'value': 'Mendoza (Argentina)'}],
#     'lead_paragraph': 'Winemakers lend class to Bordeaux blends by relying primarily on French cabernet and malbec.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/dining/01ARGENTINA4/01ARGENTINA5-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01ARGENTINA4/01ARGENTINA5-thumbWide.jpg',
#       'width': 190},
#      {'height': 399,
#       'legacy': {'xlarge': 'images/2014/01/01/dining/01ARGENTINA1/01ARGENTINA1-articleLarge.jpg',
#        'xlargeheight': '399',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01ARGENTINA1/01ARGENTINA1-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/dining/01ARGENTINA1/01ARGENTINA1-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01ARGENTINA1/01ARGENTINA1-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Dining',
#     'print_page': '4',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Dining & Wine',
#     'slideshow_credits': None,
#     'snippet': 'Winemakers lend class to Bordeaux blends by relying primarily on French cabernet and malbec.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/dining/argentina-tries-to-give-malbec-more-status.html',
#     'word_count': '609'},
#    {'_id': '52bdf46a38f0d8317f2b0243',
#     'abstract': 'David Tanis City Kitchen column offers a recipe for red onion soup with cheese toasts.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By DAVID TANIS',
#      'person': [{'firstname': 'David',
#        'lastname': 'TANIS',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'City Kitchen',
#      'kicker': 'City Kitchen',
#      'main': 'What the Tipsy Peasant Knew',
#      'print_headline': 'What the Tipsy Peasant Knew'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Cooking and Cookbooks'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '2', 'value': 'Soups'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '3', 'value': 'Onions'}],
#     'lead_paragraph': 'In France, onion soup is considered a balm for hangovers, or simple comfort for the winter weary.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/dining/01KITCH1_SPAN/01KITCH1_SPAN-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01KITCH1_SPAN/01KITCH1_SPAN-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2014/01/01/dining/01KITCH1_SPAN/01KITCH1_SPAN-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01KITCH1_SPAN/01KITCH1_SPAN-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/dining/01KITCH1_SPAN/01KITCH1_SPAN-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01KITCH1_SPAN/01KITCH1_SPAN-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Dining',
#     'print_page': '3',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Food',
#     'slideshow_credits': None,
#     'snippet': 'In France, onion soup is considered a balm for hangovers, or simple comfort for the winter weary.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/dining/what-the-tipsy-peasant-knew.html',
#     'word_count': '417'},
#    {'_id': '52bdfd3f38f0d8317f2b02ca',
#     'abstract': 'Melissa Clark A Good Appetite column offers a recipe for flaming baba au rhum.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By MELISSA CLARK',
#      'person': [{'firstname': 'Melissa',
#        'lastname': 'CLARK',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'A Good Appetite',
#      'kicker': 'A Good Appetite',
#      'main': 'Flaming Baba au Rhum Earns the Oohs and Aahs',
#      'print_headline': 'Baba au Rhum Earns the Oohs and Aahs'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Cooking and Cookbooks'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '2', 'value': 'Desserts'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '3', 'value': 'Rum'}],
#     'lead_paragraph': 'Based on an airy but rich yeast dough, the dessert can absorb more liquor than your average cake without falling apart.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/dining/01APPE2/01APPE2-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01APPE2/01APPE2-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2014/01/01/dining/01APPE2/01APPE2-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01APPE2/01APPE2-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/dining/01APPE2/01APPE2-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01APPE2/01APPE2-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Dining',
#     'print_page': '2',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Dining & Wine',
#     'slideshow_credits': None,
#     'snippet': 'Based on an airy but rich yeast dough, the dessert can absorb more liquor than your average cake without falling apart.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/dining/flaming-baba-au-rhum-earns-the-oohs-and-aahs.html',
#     'word_count': '341'},
#    {'_id': '52c1a43938f0d82ddfa1635a',
#     'abstract': None,
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By MARTHA ROSE SHULMAN',
#      'person': [{'firstname': 'Martha',
#        'lastname': 'SHULMAN',
#        'middlename': 'Rose',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Recipes for Health',
#      'kicker': 'Recipes for Health',
#      'main': 'Farro and Swiss Chard Salad With Grapefruit Vinaigrette'},
#     'keywords': [{'is_major': 'N',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Cooking and Cookbooks'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '2', 'value': 'Recipes'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Salad Dressings'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '4',
#       'value': 'Diet and Nutrition'}],
#     'lead_paragraph': 'A hearty salad with great texture and a citrus finish.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/health/01recipehealth/01recipehealth-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/health/01recipehealth/01recipehealth-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2014/01/01/health/01recipehealth/01recipehealth-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/health/01recipehealth/01recipehealth-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/health/01recipehealth/01recipehealth-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/health/01recipehealth/01recipehealth-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Science',
#     'print_page': '',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Health',
#     'slideshow_credits': None,
#     'snippet': 'A hearty salad with great texture and a citrus finish.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'recipe',
#     'web_url': 'http://www.nytimes.com/2014/01/01/health/farro-and-swiss-chard-salad-with-grapefruit-vinaigrette.html',
#     'word_count': '386'},
#    {'_id': '52c1cb8538f0d829ddebded7',
#     'abstract': 'Joel Salatin, one of most famous farmers in America, has lately turned to preaching the gospel of the forest-fed pig; calls for allowing pigs to roam and forage forests, which results in healthier soil, a greater diversity of plants, happier animals and better-tasting meat.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By KATHRYN SHATTUCK',
#      'person': [{'firstname': 'Kathryn',
#        'lastname': 'SHATTUCK',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Let Them Eat Acorns',
#      'print_headline': 'Let Them Eat Acorns',
#      'seo': 'Preaching the Gospel of the Forest-Fed Pig'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Pigs'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '2', 'value': 'Livestock'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '3',
#       'value': 'Ozark Mountains'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '4',
#       'value': 'Sustainable Living'},
#      {'is_major': 'Y',
#       'name': 'persons',
#       'rank': '5',
#       'value': 'Salatin, Joel F'}],
#     'lead_paragraph': 'Joel Salatin is the proselytizer of the pasture, raising pigs the old-fashioned way instead of closely confining them.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/dining/01PIGS1_span/01PIGS1-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01PIGS1_span/01PIGS1-thumbWide.jpg',
#       'width': 190},
#      {'height': 404,
#       'legacy': {'xlarge': 'images/2014/01/01/dining/01PIGS1_span/01PIGS1-articleLarge.jpg',
#        'xlargeheight': '404',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01PIGS1_span/01PIGS1-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/dining/01PIGS1_span/01PIGS1-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01PIGS1_span/01PIGS1-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Dining',
#     'print_page': '5',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Food',
#     'slideshow_credits': None,
#     'snippet': 'Joel Salatin is the proselytizer of the pasture, raising pigs the old-fashioned way instead of closely confining them.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/dining/preaching-the-gospel-of-the-forest-fed-pig.html',
#     'word_count': '1279'},
#    {'_id': '52c1ff4c38f0d829ddebdf4c',
#     'abstract': "List of innovative restaurants celebrating their 10th anniversaries in 2014 makes it clear that 2004 was a game-changer for New York City's restaurant scene.",
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By JEFF GORDINIER',
#      'person': [{'firstname': 'Jeff',
#        'lastname': 'GORDINIER',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': '2004, the Year That Changed How We Dine',
#      'print_headline': '2004, the Year That Changed How We Dine'},
#     'keywords': [{'is_major': 'N',
#       'name': 'organizations',
#       'rank': '5',
#       'value': 'Spotted Pig (Manhattan, NY, Restaurant)'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '1', 'value': 'Restaurants'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '3',
#       'value': 'Per Se (Manhattan, NY, Restaurant)'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'Momofuku Noodle Bar (Manhattan, NY, Restaurant)'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '2',
#       'value': 'Shake Shack'}],
#     'lead_paragraph': 'From Per Se to Shake Shack, new paths to innovative dining.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/dining/01JPYEARCOMBO1/01JPYEARCOMBO1-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01JPYEARCOMBO1/01JPYEARCOMBO1-thumbWide.jpg',
#       'width': 190},
#      {'height': 299,
#       'legacy': {'xlarge': 'images/2014/01/01/dining/01YEAR1_SPAN/01YEAR1-articleLarge.jpg',
#        'xlargeheight': '299',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01YEAR1_SPAN/01YEAR1-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/dining/01YEAR1_SPAN/01YEAR1-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01YEAR1_SPAN/01YEAR1-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Dining',
#     'print_page': '1',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Dining & Wine',
#     'slideshow_credits': None,
#     'snippet': 'From Per Se to Shake Shack, new paths to innovative dining.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/dining/2004-the-year-that-changed-how-we-dine.html',
#     'word_count': '1278'},
#    {'_id': '52c2885d38f0d829ddebe03b',
#     'abstract': None,
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By NEIL GOUGH',
#      'person': [{'firstname': 'Neil',
#        'lastname': 'GOUGH',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'China Ends Year as Asia’s Weakest Market'},
#     'keywords': [{'is_major': 'N',
#       'name': 'persons',
#       'rank': '5',
#       'value': 'Abe, Shinzo'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Initial Public Offerings'},
#      {'is_major': 'N', 'name': 'glocations', 'rank': '1', 'value': 'China'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Stocks and Bonds'},
#      {'is_major': 'N', 'name': 'glocations', 'rank': '4', 'value': 'Japan'}],
#     'lead_paragraph': 'The slump in the Shanghai Composite Index comes despite signs that Chinese policy makers are acting to rejuvenate the country’s financial markets.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/business/international/01yuan/01yuan-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/business/international/01yuan/01yuan-thumbWide.jpg',
#       'width': 190},
#      {'height': 380,
#       'legacy': {'xlarge': 'images/2014/01/01/business/international/01yuan/01yuan-articleLarge.jpg',
#        'xlargeheight': '380',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/business/international/01yuan/01yuan-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/business/international/01yuan/01yuan-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/business/international/01yuan/01yuan-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Business',
#     'print_page': '',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Business Day',
#     'slideshow_credits': None,
#     'snippet': 'The slump in the Shanghai Composite Index comes despite signs that Chinese policy makers are acting to rejuvenate the country’s financial markets.',
#     'source': 'The New York Times',
#     'subsection_name': 'International Business',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/business/international/china-ends-year-as-asias-weakest-market.html',
#     'word_count': '613'},
#    {'_id': '52c2918038f0d829ddebe048',
#     'abstract': "Russian Pres Vladimir V Putin breaks two days of silence on the twin bombings in Volgograd, vowing that Russia will continue to fight terrorists until 'their complete destruction.'",
#     'blog': [],
#     'byline': {'contributor': 'Nikolay Khalip and Viktor Klimenko contributed reporting.',
#      'original': 'By STEVEN LEE MYERS',
#      'person': [{'firstname': 'Steven',
#        'lastname': 'MYERS',
#        'middlename': 'Lee',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Putin, After Silence, Condemns Twin Bombings in Volgograd',
#      'print_headline': 'Putin, After Silence, Condemns Twin Bombings in Volgograd'},
#     'keywords': [{'is_major': 'N',
#       'name': 'persons',
#       'rank': '5',
#       'value': 'Umarov, Doku K'},
#      {'is_major': 'Y', 'name': 'glocations', 'rank': '8', 'value': 'Russia'},
#      {'is_major': 'Y',
#       'name': 'persons',
#       'rank': '1',
#       'value': 'Putin, Vladimir V'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'Deaths (Fatalities)'},
#      {'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '4',
#       'value': 'Volgograd (Russia)'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '7',
#       'value': 'Sochi (Russia)'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '2', 'value': 'Terrorism'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '6',
#       'value': 'Olympic Games (2014)'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '9',
#       'value': 'Bombs and Explosives'}],
#     'lead_paragraph': 'President Vladimir V. Putin called the attacks “inhumane terrorist acts” and vowed that Russia would fight terrorists until “their complete destruction.”',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2013/12/31/world/31russia_web/31russia_web-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2013/12/31/world/31russia_web/31russia_web-thumbWide.jpg',
#       'width': 190},
#      {'height': 404,
#       'legacy': {'xlarge': 'images/2014/01/01/world/RUSSIA/RUSSIA-articleLarge.jpg',
#        'xlargeheight': '404',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/world/RUSSIA/RUSSIA-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/world/RUSSIA/RUSSIA-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/world/RUSSIA/RUSSIA-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Foreign',
#     'print_page': '4',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'World',
#     'slideshow_credits': None,
#     'snippet': 'President Vladimir V. Putin called the attacks “inhumane terrorist acts” and vowed that Russia would fight terrorists until “their complete destruction.”',
#     'source': 'The New York Times',
#     'subsection_name': 'Europe',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/world/europe/bomb-attacks-in-russia-echo-threats-by-chechen-insurgent.html',
#     'word_count': '842'},
#    {'_id': '52c29e6d38f0d829ddebe070',
#     'abstract': None,
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By NICHOLAS KULISH',
#      'person': [{'firstname': 'Nicholas',
#        'lastname': 'KULISH',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Rebel Forces Attack Key City in South Sudan',
#      'print_headline': 'Rebel Forces Attack Key City in South Sudan'},
#     'keywords': [{'is_major': 'N',
#       'name': 'persons',
#       'rank': '3',
#       'value': 'Kiir Mayardit, Salva'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '1',
#       'value': 'South Sudan'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Defense and Military Forces'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '4',
#       'value': 'Machar, Riek'}],
#     'lead_paragraph': 'Government officials and a military spokesman indicated that the rebels were taking control of the crucial city of Bor.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2013/12/31/world/africa/20140101-SOUTHSUDAN-slide-7WS7/20140101-SOUTHSUDAN-slide-7WS7-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2013/12/31/world/africa/20140101-SOUTHSUDAN-slide-7WS7/20140101-SOUTHSUDAN-slide-7WS7-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2013/12/31/world/africa/20140101-SOUTHSUDAN-slide-7WS7/20140101-SOUTHSUDAN-slide-7WS7-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2013/12/31/world/africa/20140101-SOUTHSUDAN-slide-7WS7/20140101-SOUTHSUDAN-slide-7WS7-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2013/12/31/world/africa/20140101-SOUTHSUDAN-slide-7WS7/20140101-SOUTHSUDAN-slide-7WS7-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2013/12/31/world/africa/20140101-SOUTHSUDAN-slide-7WS7/20140101-SOUTHSUDAN-slide-7WS7-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Foreign',
#     'print_page': '',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'World',
#     'slideshow_credits': None,
#     'snippet': 'Government officials and a military spokesman indicated that the rebels were taking control of the crucial city of Bor.',
#     'source': 'The New York Times',
#     'subsection_name': 'Africa',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/world/africa/south-sudan.html',
#     'word_count': '1159'},
#    {'_id': '52c2be9d38f0d829ddebe099',
#     'abstract': "Military announces that United States has transferred three Chinese detainees from prison in Guantanamo Bay, Cuba, to Slovakia; Pentagon calls it 'significant milestone' in effort to close prison; three are the last of 22 ethnic Uighurs from China who were captured after the American invasion of Afghanistan in 2001.",
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By CHARLIE SAVAGE',
#      'person': [{'firstname': 'Charlie',
#        'lastname': 'SAVAGE',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'U.S. Frees Last of the Chinese Uighur Detainees From Guantánamo Bay',
#      'print_headline': 'U.S. Frees Last of the Chinese Uighur Detainees From Guant&aacute;namo Bay'},
#     'keywords': [{'is_major': 'N',
#       'name': 'persons',
#       'rank': '5',
#       'value': 'Sloan, Cliff'},
#      {'is_major': 'N', 'name': 'glocations', 'rank': '7', 'value': 'Slovakia'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '3',
#       'value': 'United States Defense and Military Forces'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '6',
#       'value': 'Obama, Barack'},
#      {'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '1',
#       'value': 'Guantanamo Bay Naval Base (Cuba)'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Uighurs (Chinese Ethnic Group)'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '4', 'value': 'Detainees'}],
#     'lead_paragraph': 'The Pentagon called the release of the prison’s last three Uighur detainees, originally from China and captured in Afghanistan, a “significant milestone.”',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/us/GITMO/GITMO-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/us/GITMO/GITMO-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2014/01/01/us/GITMO/GITMO-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/us/GITMO/GITMO-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/us/GITMO/GITMO-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/us/GITMO/GITMO-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'National',
#     'print_page': '13',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'U.S.',
#     'slideshow_credits': None,
#     'snippet': 'The Pentagon called the release of the prison’s last three Uighur detainees, originally from China and captured in Afghanistan, a “significant milestone.”',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/us/us-frees-last-of-uighur-detainees-from-guantanamo.html',
#     'word_count': '1000'},
#    {'_id': '52c2d56e38f0d829ddebe0c3',
#     'abstract': 'Doctors treating former Formula One champion Michael Schumacher, who sustained severe brain injuries in a skiing accident, say there is slight improvement in his condition after an overnight operation, but that he remains in critical condition.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By JOHN F. BURNS',
#      'person': [{'firstname': 'John',
#        'lastname': 'BURNS',
#        'middlename': 'F.',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Schumacher’s Condition Improves Slightly, Doctors Say',
#      'print_headline': 'Schumacher’s Condition Slightly Better, Doctors Say'},
#     'keywords': [{'is_major': 'N',
#       'name': 'subject',
#       'rank': '5',
#       'value': 'Surgery and Surgeons'},
#      {'is_major': 'Y',
#       'name': 'persons',
#       'rank': '1',
#       'value': 'Schumacher, Michael'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '6', 'value': 'Skiing'},
#      {'is_major': 'N', 'name': 'glocations', 'rank': '3', 'value': 'France'},
#      {'is_major': 'Y',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Automobile Racing'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '4',
#       'value': 'Traumatic Brain Injury'}],
#     'lead_paragraph': 'The former Formula One champion Michael Schumacher, who sustained brain injuries in a skiing accident, remained in critical condition after a second operation.',
#     'multimedia': [],
#     'news_desk': 'Sports',
#     'print_page': '8',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Sports',
#     'slideshow_credits': None,
#     'snippet': 'The former Formula One champion Michael Schumacher, who sustained brain injuries in a skiing accident, remained in critical condition after a second operation.',
#     'source': 'The New York Times',
#     'subsection_name': 'Auto Racing',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/sports/autoracing/michael-schumacher.html',
#     'word_count': '841'},
#    {'_id': '52c2d5d438f0d829ddebe0c6',
#     'abstract': 'Front Burner column; FP Patisserie offers Epiphany cake, or galette des rois, with layer of chocolate ganache; other food items and news noted.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By FLORENCE FABRICANT',
#      'person': [{'firstname': 'Florence',
#        'lastname': 'FABRICANT',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Front Burner',
#      'kicker': 'Front Burner',
#      'main': 'From Cake to Coke'},
#     'keywords': [{'is_major': 'N',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Bakeries and Baked Products'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '2', 'value': 'Pears'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '3', 'value': 'Pasta'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '4', 'value': 'Cocktails'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '5',
#       'value': 'Cooking and Cookbooks'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '6',
#       'value': 'FP Patisserie (Manhattan, NY, Restaurant)'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '7', 'value': 'Restaurants'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '8', 'value': 'Food'}],
#     'lead_paragraph': 'A slice of Epiphany, a special glass for Coca-Cola and more.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/dining/01BURNER1_SPAN/01BURNER1_SPAN-thumbWide-v2.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01BURNER1_SPAN/01BURNER1_SPAN-thumbWide-v2.jpg',
#       'width': 190},
#      {'height': 504,
#       'legacy': {'xlarge': 'images/2014/01/01/dining/01BURNER1_SPAN/01BURNER1_SPAN-articleLarge-v2.jpg',
#        'xlargeheight': '504',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01BURNER1_SPAN/01BURNER1_SPAN-articleLarge-v2.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/dining/01BURNER1_SPAN/01BURNER1-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01BURNER1_SPAN/01BURNER1-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Dining',
#     'print_page': '3',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Food',
#     'slideshow_credits': None,
#     'snippet': 'A slice of Epiphany, a special glass for Coca-Cola and more.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/dining/from-cake-to-coke.html',
#     'word_count': '765'},
#    {'_id': '52c2d60b38f0d829ddebe0c7',
#     'abstract': 'Restaurants Telepan Local, Fort Grace Local, Le Village, 1 Knickerbocker, SuperNova and The Park 112 open in New York City.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By FLORENCE FABRICANT',
#      'person': [{'firstname': 'Florence',
#        'lastname': 'FABRICANT',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Off the Menu',
#      'kicker': 'Off the Menu',
#      'main': 'A Pioneer Heads Downtown'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Restaurants'},
#      {'is_major': 'N',
#       'name': 'glocations',
#       'rank': '2',
#       'value': 'New York City'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '3', 'value': 'Wine Bars'}],
#     'lead_paragraph': 'Bill Telepan opens a TriBeCa showcase for his farm-to-table approach.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/dining/01OFF_SPAN/01OFF-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01OFF_SPAN/01OFF-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2014/01/01/dining/01OFF_SPAN/01OFF-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01OFF_SPAN/01OFF-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/dining/01OFF_SPAN/01OFF_SPAN-thumbStandard-v2.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01OFF_SPAN/01OFF_SPAN-thumbStandard-v2.jpg',
#       'width': 75}],
#     'news_desk': 'Dining',
#     'print_page': '6',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Food',
#     'slideshow_credits': None,
#     'snippet': 'Bill Telepan opens a TriBeCa showcase for his farm-to-table approach.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/dining/a-pioneer-heads-downtown.html',
#     'word_count': '471'},
#    {'_id': '52c2dd7138f0d829ddebe0cf',
#     'abstract': None,
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By CHASE STUART',
#      'person': [{'firstname': 'Chase',
#        'lastname': 'STUART',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Analysis',
#      'kicker': 'Analysis',
#      'main': 'A Statistic Behind Every Super Bowl Contender'},
#     'keywords': [{'is_major': 'N',
#       'name': 'persons',
#       'rank': '3',
#       'value': 'Manning, Peyton'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '1', 'value': 'Football'},
#      {'is_major': 'N',
#       'name': 'subject',
#       'rank': '2',
#       'value': 'Playoff Games'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'Denver Broncos'}],
#     'lead_paragraph': 'Each of the 12 teams in the N.F.L. playoffs has a big strength or a big weakness, and each has a statistic to tell the tale.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/sports/01nflscore-seahawks/01nflscore-seahawks-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/sports/01nflscore-seahawks/01nflscore-seahawks-thumbWide.jpg',
#       'width': 190},
#      {'height': 358,
#       'legacy': {'xlarge': 'images/2014/01/01/sports/01nflscore-seahawks/01nflscore-seahawks-articleLarge.jpg',
#        'xlargeheight': '358',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/sports/01nflscore-seahawks/01nflscore-seahawks-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/sports/01nflscore-manning/01nflscore-manning-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/sports/01nflscore-manning/01nflscore-manning-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Sports',
#     'print_page': '',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Sports',
#     'slideshow_credits': None,
#     'snippet': 'Each of the 12 teams in the N.F.L. playoffs has a big strength or a big weakness, and each has a statistic to tell the tale.',
#     'source': 'The New York Times',
#     'subsection_name': 'Pro Football',
#     'type_of_material': 'An Analysis',
#     'web_url': 'http://www.nytimes.com/2014/01/01/sports/football/a-statistic-behind-every-super-bowl-contender.html',
#     'word_count': '2341'},
#    {'_id': '52c2dee838f0d829ddebe0d1',
#     'abstract': None,
#     'blog': [],
#     'byline': {'organization': 'THE ASSOCIATED PRESS',
#      'original': 'By THE ASSOCIATED PRESS',
#      'person': []},
#     'document_type': 'article',
#     'headline': {'main': 'S.& P. Up 30% in Year in Biggest Increase Since 1997',
#      'print_headline': 'Wall Street Closes Out Year on Upswing'},
#     'keywords': [{'is_major': 'N',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Stocks and Bonds'}],
#     'lead_paragraph': 'Wall Street rose on the last day of 2013, joining global stock markets that were closing out at or near record highs.',
#     'multimedia': [],
#     'news_desk': 'Business',
#     'print_page': None,
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Business Day',
#     'slideshow_credits': None,
#     'snippet': 'Wall Street rose on the last day of 2013, joining global stock markets that were closing out at or near record highs.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/business/daily-stock-market-activity.html',
#     'word_count': '606'},
#    {'_id': '52c2e6a538f0d829ddebe0de',
#     'abstract': "Mark Bittman The Flexitarian column offers easy food-related New Year's resolutions that will help one move towards eating more plants and fewer animal products and processed foods.",
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By MARK BITTMAN',
#      'person': [{'firstname': 'Mark',
#        'lastname': 'BITTMAN',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'The Flexitarian',
#      'kicker': 'The Flexitarian',
#      'main': 'Sustainable Resolutions for Your Diet',
#      'print_headline': 'Sustainable Resolutions'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Cooking and Cookbooks'},
#      {'is_major': 'N', 'name': 'subject', 'rank': '2', 'value': 'Vegetables'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '3', 'value': 'New Year'}],
#     'lead_paragraph': 'Healthy eating habits only count if you stick with them, right? These tips can you help you stay resolute for the long term.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/01/dining/01FLEX_SPAN/01FLEX_SPAN-thumbWide-v3.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01FLEX_SPAN/01FLEX_SPAN-thumbWide-v3.jpg',
#       'width': 190},
#      {'height': 514,
#       'legacy': {'xlarge': 'images/2014/01/01/dining/01FLEX_SPAN/01FLEX_SPAN-articleLarge-v3.jpg',
#        'xlargeheight': '514',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01FLEX_SPAN/01FLEX_SPAN-articleLarge-v3.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/01/dining/01FLEX_SPAN/01FLEX_SPAN-thumbStandard-v3.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/01/dining/01FLEX_SPAN/01FLEX_SPAN-thumbStandard-v3.jpg',
#       'width': 75}],
#     'news_desk': 'Dining',
#     'print_page': '1',
#     'pub_date': '2014-01-01T00:00:00Z',
#     'section_name': 'Dining & Wine',
#     'slideshow_credits': None,
#     'snippet': 'Healthy eating habits only count if you stick with them, right? These tips can you help you stay resolute for the long term.',
#     'source': 'The New York Times',
#     'subsection_name': None,
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/01/dining/sustainable-resolutions-for-your-diet.html',
#     'word_count': '1292'},
#    {'_id': '52c2e73e38f0d829ddebe0df',
#     'abstract': "Many investors, although buoyed by a resurgence of stock markets in Japan and Europe in 2013, are still nervous and wary, given the swiftness of the rebounds; analysts say gains like Japan's Nikkei of 56.7 percent will be almost impossible to repeat in 2014, and could easily be reversed.",
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By JACK EWING, NEIL GOUGH and DAVID JOLLY',
#      'person': [{'firstname': 'Jack',
#        'lastname': 'EWING',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'},
#       {'firstname': 'Neil',
#        'lastname': 'GOUGH',
#        'organization': '',
#        'rank': 2,
#        'role': 'reported'},
#       {'firstname': 'David',
#        'lastname': 'JOLLY',
#        'organization': '',
#        'rank': 3,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'main': 'Global Optimism for 2014, With an Eye on Dormant Risks',
# ...
#     'word_count': '1273'},
#    {'_id': '52c8df2638f0d862ec3223bb',
#     'abstract': 'Brooklyn Nets beat Cleveland Cavaliers, 89-82, achieving consecutive victories for only the second time this season.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By ZACH SCHONBRUN',
#      'person': [{'firstname': 'Zach',
#        'lastname': 'SCHONBRUN',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Nets 89, Cavaliers 82',
#      'kicker': 'Nets 89, Cavaliers 82',
#      'main': 'New Year, New Nets With Back-to-Back Wins',
#      'print_headline': 'New Year, New Nets With Back-to-Back Wins'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '3',
#       'value': 'Cleveland Cavaliers'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '1', 'value': 'Basketball'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '2',
#       'value': 'Brooklyn Nets'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '4',
#       'value': 'Kidd, Jason'}],
#     'lead_paragraph': 'Despite a third-quarter lull, the Nets beat the Cavaliers at Barclays Center and achieved consecutive victories for only the second time this season.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/05/sports/nets/nets-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/05/sports/nets/nets-thumbWide.jpg',
#       'width': 190},
#      {'height': 901,
#       'legacy': {'xlarge': 'images/2014/01/05/sports/nets/nets-articleLarge.jpg',
#        'xlargeheight': '901',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/05/sports/nets/nets-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/05/sports/nets/nets-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/05/sports/nets/nets-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Sports',
#     'print_page': '5',
#     'pub_date': '2014-01-05T00:00:00Z',
#     'section_name': 'Sports',
#     'slideshow_credits': None,
#     'snippet': 'Despite a third-quarter lull, the Nets beat the Cavaliers at Barclays Center and achieved consecutive victories for only the second time this season.',
#     'source': 'The New York Times',
#     'subsection_name': 'Pro Basketball',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/05/sports/basketball/new-year-new-nets-with-back-to-back-wins.html',
#     'word_count': '849'},
#    {'_id': '52c8e17f38f0d862ec3223be',
#     'abstract': 'NBA Roundup; Oklahoma City Thunder rallies to earn a 115-111 victory over Minnesota Timberwolves; other basketball scores noted.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'organization': 'THE ASSOCIATED PRESS',
#      'original': 'By THE ASSOCIATED PRESS',
#      'person': []},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Roundup',
#      'kicker': 'N.B.A. Roundup',
#      'main': 'With 48 Points, Durant Lifts Thunder to a Comeback Win',
#      'print_headline': 'With 48 Points, Durant Lifts Thunder to a Comeback Win'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '3',
#       'value': 'Oklahoma City Thunder'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '1', 'value': 'Basketball'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '2',
#       'value': 'Minnesota Timberwolves'},
#      {'is_major': 'N',
#       'name': 'persons',
#       'rank': '4',
#       'value': 'Durant, Kevin'}],
#     'lead_paragraph': 'Oklahoma City’s Kevin Durant scored 23 points in the fourth quarter and hit the winning shot to defeat the Minnesota Timberwolves.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/05/sports/nba/nba-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/05/sports/nba/nba-thumbWide.jpg',
#       'width': 190},
#      {'height': 859,
#       'legacy': {'xlarge': 'images/2014/01/05/sports/nba/nba-articleLarge.jpg',
#        'xlargeheight': '859',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/05/sports/nba/nba-articleLarge.jpg',
#       'width': 600}],
#     'news_desk': 'Sports',
#     'print_page': '4',
#     'pub_date': '2014-01-05T00:00:00Z',
#     'section_name': 'Sports',
#     'slideshow_credits': None,
#     'snippet': 'Oklahoma City’s Kevin Durant scored 23 points in the fourth quarter and hit the winning shot to defeat the Minnesota Timberwolves.',
#     'source': 'The New York Times',
#     'subsection_name': 'Pro Basketball',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/05/sports/basketball/nba-roundup.html',
#     'word_count': '526'},
#    {'_id': '52c8e31038f0d862ec3223c0',
#     'abstract': 'Ashton Villa is dumped out of the FA Cup with 2-1 loss to third-tier Sheffield United; other soccer news noted.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'organization': 'THE ASSOCIATED PRESS',
#      'original': 'By THE ASSOCIATED PRESS and AGENCE FRANCE-PRESSE',
#      'person': []},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Sports Briefing | Soccer',
#      'main': 'Draw for Blackburn and Manchester City in F.A. Cup',
#      'print_headline': 'Aston Villa Is Ousted'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '5',
#       'value': 'Sheffield United (Soccer Team)'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '1', 'value': 'Soccer'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '3',
#       'value': 'Manchester City (Soccer Team)'},
#      {'is_major': 'N',
#       'name': 'organizations',
#       'rank': '2',
#       'value': 'Blackburn Rovers (Soccer Team, England)'},
#      {'is_major': 'Y',
#       'name': 'organizations',
#       'rank': '4',
#       'value': 'Aston Villa (Soccer Team)'}],
#     'lead_paragraph': 'Goalkeeper Costel Pantilimon gave a gift to Blackburn as 10-man Manchester City was held to a 1-1 draw in the third round of the F.A. Cup on Saturday.',
#     'multimedia': [],
#     'news_desk': 'Sports',
#     'print_page': '2',
#     'pub_date': '2014-01-05T00:00:00Z',
#     'section_name': 'Sports',
#     'slideshow_credits': None,
#     'snippet': 'Goalkeeper Costel Pantilimon gave a gift to Blackburn as 10-man Manchester City was held to a 1-1 draw in the third round of the F.A. Cup on Saturday.',
#     'source': 'The New York Times',
#     'subsection_name': 'Soccer',
#     'type_of_material': 'Brief',
#     'web_url': 'http://www.nytimes.com/2014/01/05/sports/soccer/draw-for-blackburn-and-manchester-city-in-fa-cup.html',
#     'word_count': '512'},
#    {'_id': '52c8e54938f0d862ec3223c1',
#     'abstract': 'Dennis Rodman name a team of former NBA players to participate in an exhibition game in Pyongyang, North Korea.',
#     'blog': [],
#     'byline': {'contributor': '',
#      'organization': 'THE ASSOCIATED PRESS',
#      'original': 'By THE ASSOCIATED PRESS',
#      'person': []},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Sports Briefing | Basketball',
#      'main': 'Rodman-Led Team to N. Korea',
#      'print_headline': 'Rodman-Led Team to N. Korea'},
#     'keywords': [{'is_major': 'Y',
#       'name': 'persons',
#       'rank': '2',
#       'value': 'Rodman, Dennis'},
#      {'is_major': 'Y', 'name': 'subject', 'rank': '1', 'value': 'Basketball'},
#      {'is_major': 'Y',
#       'name': 'glocations',
#       'rank': '3',
#       'value': 'North Korea'}],
#     'lead_paragraph': 'Dennis Rodman has named a team of former N.B.A. players to participate in an exhibition game in Pyongyang, North Korea.',
#     'multimedia': [],
#     'news_desk': 'Sports',
#     'print_page': '2',
#     'pub_date': '2014-01-05T00:00:00Z',
#     'section_name': 'Sports',
#     'slideshow_credits': None,
#     'snippet': 'Dennis Rodman has named a team of former N.B.A. players to participate in an exhibition game in Pyongyang, North Korea.',
#     'source': 'The New York Times',
#     'subsection_name': 'Pro Basketball',
#     'type_of_material': 'Brief',
#     'web_url': 'http://www.nytimes.com/2014/01/05/sports/basketball/rodman-led-team-to-n-korea.html',
#     'word_count': '74'},
#    {'_id': '52c8ea6138f0d862ec3223cb',
#     'abstract': None,
#     'blog': [],
#     'byline': [],
#     'document_type': 'article',
#     'headline': {'main': 'Rebecca Garcia and Andrew Spiegel',
#      'print_headline': 'Rebecca Garcia, Andrew Spiegel'},
#     'keywords': [{'is_major': 'N',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Weddings and Engagements'}],
#     'lead_paragraph': 'Guests thought it was an engagement party. Surprise!',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/05/fashion/weddings/05GARCIAjpg/05GARCIAjpg-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/05/fashion/weddings/05GARCIAjpg/05GARCIAjpg-thumbWide.jpg',
#       'width': 190},
#      {'height': 547,
#       'legacy': {'xlarge': 'images/2014/01/05/fashion/weddings/05GARCIAjpg/05GARCIAjpg-articleLarge.jpg',
#        'xlargeheight': '547',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/05/fashion/weddings/05GARCIAjpg/05GARCIAjpg-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/05/fashion/weddings/05GARCIAjpg/05GARCIAjpg-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/05/fashion/weddings/05GARCIAjpg/05GARCIAjpg-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Society',
#     'print_page': '12',
#     'pub_date': '2014-01-05T00:00:00Z',
#     'section_name': 'Fashion & Style',
#     'slideshow_credits': None,
#     'snippet': 'Guests thought it was an engagement party. Surprise!',
#     'source': 'The New York Times',
#     'subsection_name': 'Weddings/Celebrations',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/05/fashion/weddings/rebecca-garcia-and-andrew-spiegel.html',
#     'word_count': '137'},
#    {'_id': '52c8ea6138f0d862ec3223cc',
#     'abstract': None,
#     'blog': [],
#     'byline': [],
#     'document_type': 'article',
#     'headline': {'main': 'Alexandra Andrews, Christopher Beha',
#      'print_headline': 'Alexandra Andrews, Christopher Beha'},
#     'keywords': [{'is_major': 'N',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Weddings and Engagements'}],
#     'lead_paragraph': 'The bride is studying at the Pratt Institute; the groom is a deputy editor at Harper’s.',
#     'multimedia': [],
#     'news_desk': 'Society',
#     'print_page': '11',
#     'pub_date': '2014-01-05T00:00:00Z',
#     'section_name': 'Fashion & Style',
#     'slideshow_credits': None,
#     'snippet': 'The bride is studying at the Pratt Institute; the groom is a deputy editor at Harper’s.',
#     'source': 'The New York Times',
#     'subsection_name': 'Weddings/Celebrations',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/05/fashion/weddings/alexandra-andrews-christopher-beha.html',
#     'word_count': '231'},
#    {'_id': '52c8ea6b38f0d862ec3223d1',
#     'abstract': None,
#     'blog': [],
#     'byline': {'contributor': '',
#      'original': 'By MARGAUX LASKEY',
#      'person': [{'firstname': 'Margaux',
#        'lastname': 'LASKEY',
#        'organization': '',
#        'rank': 1,
#        'role': 'reported'}]},
#     'document_type': 'article',
#     'headline': {'content_kicker': 'Barbara Galletly, Grant Passmore',
#      'main': 'A Romance Goes From Head to Heart',
#      'print_headline': 'A Romance Goes From Head to Heart'},
#     'keywords': [{'is_major': 'N',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Weddings and Engagements'}],
#     'lead_paragraph': 'A long email correspondence turns into a real relationship.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/05/fashion/weddings/05GALLETLY/05GALLETLY-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/05/fashion/weddings/05GALLETLY/05GALLETLY-thumbWide.jpg',
#       'width': 190},
#      {'height': 400,
#       'legacy': {'xlarge': 'images/2014/01/05/fashion/weddings/05GALLETLY/05GALLETLY-articleLarge.jpg',
#        'xlargeheight': '400',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/05/fashion/weddings/05GALLETLY/05GALLETLY-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/05/fashion/weddings/05GALLETLY/05GALLETLY-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/05/fashion/weddings/05GALLETLY/05GALLETLY-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Society',
#     'print_page': '11',
#     'pub_date': '2014-01-05T00:00:00Z',
#     'section_name': 'Fashion & Style',
#     'slideshow_credits': None,
#     'snippet': 'A long email correspondence turns into a real relationship.',
#     'source': 'The New York Times',
#     'subsection_name': 'Weddings/Celebrations',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/05/fashion/weddings/a-romance-goes-from-head-to-heart.html',
#     'word_count': '555'},
#    {'_id': '52c8ea5e38f0d862ec3223ca',
#     'abstract': None,
#     'blog': [],
#     'byline': [],
#     'document_type': 'article',
#     'headline': {'main': 'Rochelle Behrens and Sacha Litman',
#      'print_headline': 'Rochelle Behrens, Sacha Litman'},
#     'keywords': [{'is_major': 'N',
#       'name': 'subject',
#       'rank': '1',
#       'value': 'Weddings and Engagements'}],
#     'lead_paragraph': 'The bride owns a shirtmaking company; the groom works in data analytics.',
#     'multimedia': [{'height': 126,
#       'legacy': {'wide': 'images/2014/01/05/fashion/weddings/05BEHRENSjpg/05BEHRENSjpg-thumbWide.jpg',
#        'wideheight': '126',
#        'widewidth': '190'},
#       'subtype': 'wide',
#       'type': 'image',
#       'url': 'images/2014/01/05/fashion/weddings/05BEHRENSjpg/05BEHRENSjpg-thumbWide.jpg',
#       'width': 190},
#      {'height': 543,
#       'legacy': {'xlarge': 'images/2014/01/05/fashion/weddings/05BEHRENSjpg/05BEHRENSjpg-articleLarge.jpg',
#        'xlargeheight': '543',
#        'xlargewidth': '600'},
#       'subtype': 'xlarge',
#       'type': 'image',
#       'url': 'images/2014/01/05/fashion/weddings/05BEHRENSjpg/05BEHRENSjpg-articleLarge.jpg',
#       'width': 600},
#      {'height': 75,
#       'legacy': {'thumbnail': 'images/2014/01/05/fashion/weddings/05BEHRENSjpg/05BEHRENSjpg-thumbStandard.jpg',
#        'thumbnailheight': '75',
#        'thumbnailwidth': '75'},
#       'subtype': 'thumbnail',
#       'type': 'image',
#       'url': 'images/2014/01/05/fashion/weddings/05BEHRENSjpg/05BEHRENSjpg-thumbStandard.jpg',
#       'width': 75}],
#     'news_desk': 'Society',
#     'print_page': '11',
#     'pub_date': '2014-01-05T00:00:00Z',
#     'section_name': 'Fashion & Style',
#     'slideshow_credits': None,
#     'snippet': 'The bride owns a shirtmaking company; the groom works in data analytics.',
#     'source': 'The New York Times',
#     'subsection_name': 'Weddings/Celebrations',
#     'type_of_material': 'News',
#     'web_url': 'http://www.nytimes.com/2014/01/05/fashion/weddings/rochelle-behrens-and-sacha-litman.html',
#     'word_count': '206'},
#    ...],
#   'meta': {'hits': 7968}}}

# %%
s["response"]["docs"][3]['type_of_material']
# Out:
# 'News'

# %%
sss=[]
for s in s["response"]["docs"]:
    sss.append(s['type_of_material'])

# %%
typelist=[]
for file in glob.glob(os.path.dirname(os.getcwd())+"/raw data/archive/*.json"):
    data=readjson(file)
    for archive in data["response"]["docs"]:
        typelist.append(archive['type_of_material'])

# %%
FreqDist(typelist)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-1d86fc5ed3d8> in <module>()
# ----> 1 FreqDist(typelist)
#
# NameError: name 'FreqDist' is not defined
