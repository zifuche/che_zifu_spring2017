# %%
from pandas import Series, DataFrame
import pandas as pd
import os
import numpy as np
import datetime as dt

# %%
df = pd.read_csv(os.getcwd()+'/employee_compensation.csv')

df2=df[df["Year Type"]=="Calendar"]

# %%
data={"Salaries":[df2["Salaries"].mean()],"Overtime":[df2["Overtime"].mean()],"Other Salaries":[df2["Other Salaries"].mean()],"Total Salary":[df2["Total Salary"].mean()],"Retirement":[df2["Retirement"].mean()],"Health/Dental":[df2["Health/Dental"].mean()],"Other Benefits":[df2["Other Benefits"].mean()],"Total Benefits":[df2["Total Benefits"].mean()],"Total Compensation":[df2["Total Compensation"].mean()]}


dtt=DataFrame(data)

# %%
df2.head()
# Out:
#   Year Type  Year  Organization Group Code  \
# 0  Calendar  2013                        2
# 2  Calendar  2016                        3
# 3  Calendar  2016                        6
# 5  Calendar  2016                        2
# 7  Calendar  2014                        6
#
#                          Organization Group Department Code  \
# 0   Public Works, Transportation & Commerce             AIR
# 2  Human Welfare & Neighborhood Development             WOM
# 3          General Administration & Finance             HRD
# 5   Public Works, Transportation & Commerce             DBI
# 7          General Administration & Finance             ADM
#
#                              Department  Union Code  \
# 0                    Airport Commission        38.0
# 2     Department of the Status of Women       323.0
# 3                       Human Resources       790.0
# 5     Department of Building Inspection       790.0
# 7  General Services Agency - City Admin       790.0
#
# ...

# %%
dtt       #average salery
# Out:
#    Health/Dental  Other Benefits  Other Salaries     Overtime    Retirement  \
# 0    9197.973054     4798.753051     3834.299165  4591.135547  13087.974695
#
#        Salaries  Total Benefits  Total Compensation  Total Salary
# 0  64973.851896    27084.700801       100483.987409  73399.286608

# %%
df2.query('Overtime>Salaries*0.05')
# Out:
#        Year Type  Year  Organization Group Code  \
# 14      Calendar  2014                        5
# 23      Calendar  2016                        5
# 38      Calendar  2013                        2
# 40      Calendar  2015                        1
# 44      Calendar  2015                        1
# 48      Calendar  2013                        2
# 50      Calendar  2014                        1
# 56      Calendar  2013                        2
# 57      Calendar  2015                        4
# 65      Calendar  2016                        2
# 81      Calendar  2015                        1
# 83      Calendar  2016                        1
# 108     Calendar  2014                        2
# 116     Calendar  2015                        2
# 120     Calendar  2016                        1
# 123     Calendar  2013                        2
# 137     Calendar  2014                        2
# 141     Calendar  2015                        2
# ...

# %%
df3=df2[["Job Family","Total Benefits","Total Compensation"]]

# %%
df3
# Out:
#                             Job Family  Total Benefits  Total Compensation
# 0                     Journeyman Trade        41432.55           143916.66
# 2                           Management           67.28              267.28
# 3                        Legal & Court          736.13             2519.13
# 5        Clerical, Secretarial & Steno        35843.78           119851.55
# 7                  Public Service Aide        11956.70            36136.70
# 8               Housekeeping & Laundry        30294.53            94113.95
# 10                      Dietary & Food        32908.84           111084.25
# 13                    Journeyman Trade         2367.57             8044.63
# 14          Agriculture & Horticulture        34064.57           117266.41
# 15                          Park & Zoo        28138.44            77617.59
# 17      Computer Operatns & Repro Svcs         4284.82            17797.92
# ...

# %%
df4=df3.groupby(["Job Family"]).mean()
df4
# Out:
#                                 Total Benefits  Total Compensation
# Job Family
# Administrative & Mgmt (Unrep)     58060.547576       247806.655758
# Administrative Secretarial        28172.247500        99424.515500
# Administrative-DPW/PUC            41308.831921       156398.468644
# Administrative-Labor & Trades     40396.365472       163204.030849
# Agriculture & Horticulture        25483.396273        81719.509350
# Airport Operation                 31652.253813       108701.639607
# Appraisal & Taxation              29159.093239        96818.036129
# Budget, Admn & Stats Analysis     27918.238713        95053.861733
# Clerical, Secretarial & Steno     21549.044311        66517.545454
# Community Development             29071.209352        97753.808432
# Computer Operatns & Repro Svcs    20184.340740        64309.354362
# Construction Inspection           32847.573645       118385.610078
# Construction Project Mgmt         39318.034343       152716.358451
# ...

# %%
df4["PERCENTAGE"]=df4["Total Benefits"]/df4["Total Compensation"]

# %%
df4
# Out:
#                                 Total Benefits  Total Compensation  PERCENTAGE
# Job Family
# Administrative & Mgmt (Unrep)     58060.547576       247806.655758    0.234298
# Administrative Secretarial        28172.247500        99424.515500    0.283353
# Administrative-DPW/PUC            41308.831921       156398.468644    0.264126
# Administrative-Labor & Trades     40396.365472       163204.030849    0.247521
# Agriculture & Horticulture        25483.396273        81719.509350    0.311840
# Airport Operation                 31652.253813       108701.639607    0.291185
# Appraisal & Taxation              29159.093239        96818.036129    0.301174
# Budget, Admn & Stats Analysis     27918.238713        95053.861733    0.293710
# Clerical, Secretarial & Steno     21549.044311        66517.545454    0.323960
# Community Development             29071.209352        97753.808432    0.297392
# Computer Operatns & Repro Svcs    20184.340740        64309.354362    0.313863
# ...

# %%
df4[["PERCENTAGE"]].to_csv('Q2-2.csv')
